# %%
from PIL import Image, ImageDraw, ImageFont, ImageFile, ImageEnhance

# %%
im1 = Image.open('image1.jpg')
im2 = Image.open('image2.png')

# %%
print(im1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=184x123 at 0x27725BF42E0>

# %%
im1.show()

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=184x123>

# %%
im1.info
# Out:
# {'jfif': 257, 'jfif_version': (1, 1), 'jfif_unit': 0, 'jfif_density': (1, 1)}

# %%
print(im1.mode, im1.size)
print(im1.mode, im1.size)
# Out:
# RGB (184, 123)
# RGB (184, 123)

# %%
im1.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=184x123>

# %%
im1.transpose(method=Image.Transpose.FLIP_TOP_BOTTOM)
# Out:
# <PIL.Image.Image image mode=RGB size=184x123>

# %%
im1.resize((300,300)).show()

# %%
im1.crop([100,100,500,500]).show()

# %%
w,h = im1.size
im1.resize((w*2,h*2)).save('image1_2x.jpg')

# %%
w,h = im2.size
im2_half = im2.resize((w//2, h//2))
im2_half.size
# Out:
# (104, 61)

# %%
logo = Image.open('copied.jpg')
logo_small = logo.resize((logo.width//4, logo.height//4))
logo_small
# Out:
# <PIL.Image.Image image mode=RGB size=54x30>

# %%
im1_copy = im1.copy() # copy to save the original as is.
im1_copy.paste(logo_small, (100,100))
im1_copy
# Out:
# <PIL.Image.Image image mode=RGB size=184x123>
